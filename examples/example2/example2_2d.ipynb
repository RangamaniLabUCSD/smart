# %% [markdown]
# # Example for system in Meyers, Craig and Odde 2006
#
# Geometry is divided into 2 domains - one surface and one volume:
# - plasma membrane (PM) - cell surface
# - cytosol - intracellular volume
#
# This model has a single species, A, which is phosphorylated at the cell membrane. The unphosphorylated form of A ($A_{dephos}$) can be computed from mass conservation; everywhere $c_{A_{phos}} + c_{A_{dephos}} = c_{Tot}$, which is a constant in both time and space if the phosphorylated vs. unphosphorylated forms have the same diffusion coefficient.
#
# There are two reactions - one in the PM and other in the cytosol. At the membrane, $A_{dephos}$ is phosphorylated by a first-order reaction with rate $k_{kin}$, and in the cytosolic volume, $A_{phos}$ is dephosphorylated by a first order reaction with rate $k_p$.
#
# Currently, this code includes a dummy variable, kinMem, which represents relative kinase activity at the membrane, currently set as constant at 1 (dimensionless). Without this additional species, the code currently does not solve the system (it seems that there needs to be variables in at least two compartments to solve the monolithic system).

# %%
import os

import dolfin as d
import sympy as sym
import numpy as np

from smart import config, common, mesh, model
from smart.units import unit
from smart.model_assembly import Compartment, Parameter, Reaction, Species, sbmodel_from_locals
from matplotlib import pyplot as plt
# Out:
# QStandardPaths: XDG_RUNTIME_DIR not set, defaulting to '/tmp/runtime-root'

# %% [markdown]
# First, we define the various units for the inputs

# %%
# Aliases - base units
uM = unit.uM
um = unit.um
molecule = unit.molecule
sec = unit.sec
dimensionless = unit.dimensionless
# Aliases - units used in model
D_unit = um**2 / sec
flux_unit = molecule / (um**2 * sec)
vol_unit = uM
surf_unit = molecule / um**2

# %% [markdown]
# Next we generate the model.

# %%
def make_model(a,b):
    # =============================================================================================
    # Species
    # =============================================================================================
    # name, initial concentration, concentration units, diffusion, diffusion units, compartment
    Ainit = f"10*exp(-((x-{a}/4.0)**2+(y-{b}/2.0)**2)/.1)"
    Binit = f"exp(-((x-3.0*{a}/4.0)**2+(y-{b}/2.0)**2)/.1)"
    A = Species("A", Ainit, surf_unit, 1.0, D_unit, "PM1")
#     B = Species("B", Binit, surf_unit, 1.0, D_unit, "PM2")
    # kinMem = Species("kinMem", 1.0, dimensionless, 0.0, D_unit, "PM") # dummy variable; without this, the current version of SMART throws an error

    # =============================================================================================
    # Compartments
    # =============================================================================================
    # name, topological dimensionality, length scale units, marker value
    PM1 = Compartment("PM1", 2, um, 1)
#     PM2 = Compartment("PM2", 2, um, 2)
    junction = Compartment("junction", 1, um, 3)

    # =============================================================================================
    # Parameters and Reactions
    # =============================================================================================
    # Dephosphorylation of Aphos in the cytosol
    kdeg = Parameter("kdeg", 0, 1/sec)
    r1 = Reaction("r1", ["A"], [], param_map={"kon": "kdeg"},
         eqn_f_str="kon*A", species_map={"A": "A"})
#     r2 = Reaction("r2", ["B"], [], param_map={"kon": "kdeg"},
#          eqn_f_str="kon*B", species_map={"B": "B"})
    k_cross = Parameter("k_cross", 10, um/sec)
    cref = Parameter("cref", 1, surf_unit)
    r3 = Reaction("r3", ["A"], [], param_map={"kon": "k_cross", "cref": "cref"},
          eqn_f_str="kon*(A - cref)", explicit_restriction_to_domain="junction")

    # =============================================================================================
    # Gather all parameters, species, compartments and reactions
    # =============================================================================================
    return sbmodel_from_locals(locals().values())

# %% [markdown]
# We load the model generated above, and load in the mesh we will use in this example, iterating over 10 different values of cell radius, log-spaced between 1 and 10.

# %%
b = 1.; a = 5.
pc, sc, cc, rc = make_model(a,b)
# Create mesh
m = 10; n = int(a/b)*m
rect_mesh = d.RectangleMesh(d.Point(0.0, 0.0), d.Point(a, b), n, m)
mf2 = d.MeshFunction("size_t", rect_mesh, 2, 1)
for f in d.faces(rect_mesh):
    x_vals = np.zeros(3)
    idx = 0
    for vertex in d.vertices(f):
        x_vals[idx] = vertex.point().array()[0]
        idx = idx+1
    if np.mean(x_vals) > a/2.0:
        mf2[f] = 2
mf1 = d.MeshFunction("size_t", rect_mesh, 1, 0)
for e in d.edges(rect_mesh):
    x_vals = np.zeros(2)
    idx = 0
    for vertex in d.vertices(e):
        x_vals[idx] = vertex.point().array()[0]
        idx = idx+1
    if np.isclose(np.mean(x_vals), a/2.0):
        mf1[e] = 3
# Write mesh and meshfunctions to file
os.makedirs(f"rect_mesh", exist_ok=True)
filename = f"rect_mesh/rect_mesh"
hdf5 = d.HDF5File(rect_mesh.mpi_comm(), filename + ".h5", "w")
hdf5.write(rect_mesh, "/mesh")
hdf5.write(mf2, "/mf2")
hdf5.write(mf1, "/mf1")
d.File(f"{filename}_mf2.pvd") << mf2
d.File(f"{filename}_mf1.pvd") << mf1

# # Define solvers
parent_mesh = mesh.ParentMesh(
    mesh_filename=f"{filename}.h5",
    mesh_filetype="hdf5",
    name="parent_mesh",
)
configCur = config.Config()
modelCur = model.Model(pc, sc, cc, rc, configCur, parent_mesh)
configCur.solver.update(
    {
        "final_t": 1,
        "initial_dt": 0.01,
        "time_precision": 6,
        "use_snes": True,
        "print_assembly": False,
    }
)

modelCur.initialize(initialize_solver=False)
modelCur.initialize_discrete_variational_problem_and_solver()
# Write initial condition(s) to file
results = dict()
os.makedirs(f"resultsRect", exist_ok=True)
for species_name, species in modelCur.sc.items:
    results[species_name] = d.XDMFFile(
        modelCur.mpi_comm_world, f"resultsRect/{species_name}.xdmf"
    )
    results[species_name].parameters["flush_output"] = True
    results[species_name].write(modelCur.sc[species_name].u["u"], modelCur.t)

# Solve
while True:
    # Solve the system
    modelCur.monolithic_solve()
    # Save results for post processing
    for species_name, species in modelCur.sc.items:
        results[species_name].write(modelCur.sc[species_name].u["u"], modelCur.t)
    # End if we've passed the final time
    if modelCur.t >= modelCur.final_t:
        break

# compute steady state solution at the end of each run
dx = d.Measure("dx",domain = modelCur.cc['PM1'].dolfin_mesh)
int_val = d.assemble(modelCur.sc['A'].u['u']*dx)
SA = d.assemble(1.0*dx)
ss_val = int_val / SA
# Out:
# 2023-05-15 14:27:56,631 smart.model_assembly - DEBUG - Creating dolfin object for space-dependent initial condition A (model_assembly.py:675)
#  2023-05-15 14:27:57,175 smart.mesh - INFO - HDF5 mesh, "parent_mesh", successfully loaded from file: rect_mesh/rect_mesh.h5! (mesh.py:205)
#
#
#
#  2023-05-15 14:27:57,203 smart.model - DEBUG - Checking validity of model (step 1 of ZZ) (model.py:209)
#
#
# 2023-05-15 14:27:57,207 smart.model - DEBUG - Check that mesh/compartment dimensionalities match (model.py:285)
# 2023-05-15 14:27:57,213 smart.model - DEBUG - Checking for namespace conflicts (model.py:314)
#  2023-05-15 14:27:57,216 smart.model - DEBUG - Step 1 of initialization completed successfully! (model.py:213)
#
#
#
#  2023-05-15 14:27:57,219 smart.model - DEBUG - Cross-Container Dependent Initializations (step 2 of ZZ) (model.py:221)
#
#
# 2023-05-15 14:27:57,225 smart.model - DEBUG - Turning reactions into unsigned symbolic flux strings (model.py:368)
# 2023-05-15 14:27:57,276 smart.model - DEBUG - Make sure all reactions have parameters/species defined (model.py:411)
# 2023-05-15 14:27:57,288 smart.model - DEBUG - Linking parameters, species, and compartments to reactions (model.py:432)
# 2023-05-15 14:27:57,292 smart.model - DEBUG - Checking for unused parameters, species, or compartments (model.py:492)
# 2023-05-15 14:27:57,296 smart.model - DEBUG - Linking compartments and compartment dimensionality to species (model.py:547)
# 2023-05-15 14:27:57,300 smart.model - DEBUG - Linking species to compartments (model.py:556)
# 2023-05-15 14:27:57,304 smart.model - DEBUG - Getting indices for species for each compartment (model.py:565)
#  2023-05-15 14:27:57,497 smart.model - DEBUG - Step 2 of initialization completed successfully! (model.py:234)
#
#
#
#  2023-05-15 14:27:57,499 smart.model - DEBUG - Mesh-related Initializations (step 3 of ZZ) (model.py:241)
#
#
# 2023-05-15 14:27:57,501 smart.model - DEBUG - Defining child meshes (model.py:577)
# 2023-05-15 14:27:57,503 smart.model - DEBUG - Defining parent mesh functions (model.py:596)
# 2023-05-15 14:27:57,542 smart.model - DEBUG - Extracting submeshes using MeshView (model.py:601)
# 2023-05-15 14:27:57,547 smart.model - DEBUG - Building MeshView mappings between all child mesh pairs (model.py:607)
#
#
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# !!!!!!!! 2023-05-15 14:27:57,550 smart.model - DEBUG - DEBUGGING 3_5, 3_6 (mesh intersections) (model.py:249) !!!!!!!!
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
#
#
# 2023-05-15 14:27:57,552 smart.model - DEBUG - Getting integration measures for parent mesh and child meshes (model.py:636)
# ..... 2023-05-15 14:27:57,560 smart.model - DEBUG - Step 3 of initialization completed successfully! (model.py:253) .....
#
#
#
#  2023-05-15 14:27:57,564 smart.model - DEBUG - Dolfin Initializations (step 4 of ZZ) (model.py:260)
#
#
# 2023-05-15 14:27:57,567 smart.model - DEBUG - Defining dolfin function spaces for compartments (model.py:683)
# 2023-05-15 14:27:57,570 smart.model - DEBUG - Defining function space for PM1      (dim: 2, species: 1, dofs: 0) (model.py:693)
# 2023-05-15 14:27:57,581 smart.model - DEBUG - Defining dolfin functions (model.py:759)
# 2023-05-15 14:27:57,589 smart.model - DEBUG - Extracting subfunctions/function spaces/dofmap for each species (model.py:797)
# 2023-05-15 14:27:57,595 smart.model - DEBUG - Naming functions and subfunctions (model.py:816)
# 2023-05-15 14:27:57,599 smart.model - DEBUG - Checking that dolfin functions were created correctly (model.py:829)
# 2023-05-15 14:27:57,602 smart.model - DEBUG - Set function values to initial conditions (model.py:858)
#
#
#
#  2023-05-15 14:27:57,610 smart.model - DEBUG - Dolfin fluxes, forms, and problems+solvers (step 5 of ZZ) (model.py:271)
#
#
# 2023-05-15 14:27:57,612 smart.model - DEBUG - Convert reactions to flux objects (model.py:871)
# 2023-05-15 14:27:57,614 smart.model_assembly - DEBUG - Getting fluxes for reaction r3 (model_assembly.py:994)
#  2023-05-15 14:27:57,644 smart.model_assembly - DEBUG - DEBUGGING INTEGRATION MEASURE (only fully defined domains are enabled for now) (model_assembly.py:1250)
# 2023-05-15 14:27:57,670 smart.model_assembly - DEBUG - Getting fluxes for reaction r1 (model_assembly.py:994)
# 2023-05-15 14:27:57,696 smart.model - DEBUG - Creating functional forms (model.py:883)
# 2023-05-15 14:27:57,712 smart.model - DEBUG - Compartment junction has no diffusive forms. (model.py:986)
#
#
#
#  2023-05-15 14:27:57,714 smart.model - DEBUG - Model finished initialization! (model.py:199)
#
#
# /usr/lib/python3/dist-packages/pandas/core/dtypes/cast.py:1542: UnitStrippedWarning: The unit of the quantity is stripped when downcasting to ndarray.
#   result[:] = values
# /usr/lib/python3/dist-packages/pandas/core/dtypes/cast.py:1542: UnitStrippedWarning: The unit of the quantity is stripped when downcasting to ndarray.
#   result[:] = values
# /usr/lib/python3/dist-packages/pandas/core/dtypes/cast.py:1542: UnitStrippedWarning: The unit of the quantity is stripped when downcasting to ndarray.
#   result[:] = values
#  2023-05-15 14:27:57,785 smart.model_assembly - INFO - ╒═════════╤═══════════════════════╤═════════════════════╤════════════╤═════════╤═════════╕
# │         │ quantity              │ is_time_dependent   │ sym_expr   │ notes   │ group   │
# ╞═════════╪═══════════════════════╪═════════════════════╪════════════╪═════════╪═════════╡
# │ cref    │ 1.00×10⁰ molecule/µm² │ False               │            │         │         │
# ├─────────┼───────────────────────┼─────────────────────┼────────────┼─────────┼─────────┤
# │ k_cross │ 1.00×10¹ µm/s         │ False               │            │         │         │
# ├─────────┼───────────────────────┼─────────────────────┼────────────┼─────────┼─────────┤
# │ kdeg    │ 0.00×10⁰ 1/s          │ False               │            │         │         │
# ╘═════════╧═══════════════════════╧═════════════════════╧════════════╧═════════╧═════════╛ (model_assembly.py:287)
# /usr/lib/python3/dist-packages/pandas/core/dtypes/cast.py:1542: UnitStrippedWarning: The unit of the quantity is stripped when downcasting to ndarray.
#   result[:] = values
#  2023-05-15 14:27:57,814 smart.model_assembly - INFO - ╒════╤════════════════════╤═════════════╤════════════════╕
# │    │ compartment_name   │   dof_index │ Diffusion      │
# ╞════╪════════════════════╪═════════════╪════════════════╡
# │ A  │ PM1                │           0 │ 1.00×10⁰ µm²/s │
# ╘════╧════════════════════╧═════════════╧════════════════╛ (model_assembly.py:287)
# /usr/lib/python3/dist-packages/pandas/core/dtypes/cast.py:1542: UnitStrippedWarning: The unit of the quantity is stripped when downcasting to ndarray.
#   result[:] = values
# /usr/lib/python3/dist-packages/pandas/core/dtypes/cast.py:1542: UnitStrippedWarning: The unit of the quantity is stripped when downcasting to ndarray.
#   result[:] = values
#  2023-05-15 14:27:57,859 smart.model_assembly - INFO - ╒══════════╤═══════════╤══════════════════╤═══════════════╤════════════════╤════════════╤══════════════════╤═════════════╤═══════════════╤══════════════╕
# │          │   mesh_id │   dimensionality │   num_species │   num_vertices │   num_dofs │   num_dofs_local │   num_cells │   cell_marker │ nvolume      │
# ╞══════════╪═══════════╪══════════════════╪═══════════════╪════════════════╪════════════╪══════════════════╪═════════════╪═══════════════╪══════════════╡
# │ junction │        21 │                1 │             0 │             11 │          0 │                0 │          10 │             3 │ 1.00×10⁰ µm  │
# ├──────────┼───────────┼──────────────────┼───────────────┼────────────────┼────────────┼──────────────────┼─────────────┼───────────────┼──────────────┤
# │ PM1      │        27 │                2 │             1 │            286 │        286 │              286 │         500 │             1 │ 2.50×10⁰ µm² │
# ╘══════════╧═══════════╧══════════════════╧═══════════════╧════════════════╧════════════╧══════════════════╧═════════════╧═══════════════╧══════════════╛ (model_assembly.py:287)
#  2023-05-15 14:27:57,876 smart.model_assembly - INFO - ╒════╤═══════╤═══════╤════════════════════╤═════════════╕
# │    │ lhs   │ rhs   │ eqn_f_str          │ eqn_r_str   │
# ╞════╪═══════╪═══════╪════════════════════╪═════════════╡
# │ r3 │ ['A'] │ []    │ k_cross*(A - cref) │             │
# ├────┼───────┼───────┼────────────────────┼─────────────┤
# │ r1 │ ['A'] │ []    │ A*kdeg             │             │
# ╘════╧═══════╧═══════╧════════════════════╧═════════════╛ (model_assembly.py:287)
# 2023-05-15 14:27:57,879 smart.model - DEBUG - Formulating problem as F(u;v) == 0 for newton iterations (model.py:995)
# 2023-05-15 14:27:57,960 smart.model - DEBUG - Initial L2-norm of compartment PM1 is 11.539833930068333 (model.py:1026)
# ..... 2023-05-15 14:27:57,961 smart.model - WARNING - Warning! Initial L2-norm of compartment PM1 is 11.539833930068333 (possibly too large). (model.py:1031) .....
# 2023-05-15 14:27:57,962 smart.model - DEBUG - Using SNES solver (model.py:1039)
# 2023-05-15 14:27:57,973 smart.solvers - DEBUG - cpu 0: (ijk)=(0, 0, 0) (286, 286, 286, 286) (solvers.py:267)
# 2023-05-15 14:27:57,975 smart.solvers - DEBUG - cpu 0: (ijk)=(0, 0, 1) (286, 286, 286, 286) (solvers.py:267)
#  2023-05-15 14:27:57,979 smart.solvers - INFO - Jpetsc_nest assembled, size = (286, 286) (solvers.py:318)
#
#
# ...........................................................................................................................
# ...........................................................................................................................
# ..... 2023-05-15 14:27:58,050 smart.model - INFO - Beginning time-step 1 [time=0.010000, dt=0.010000] (model.py:1521) .....
# ...........................................................................................................................
# ...........................................................................................................................
#
#
#  2023-05-15 14:27:58,051 smart.model - INFO - Solving using PETSc.SNES Solver (model.py:1530)
# 2023-05-15 14:27:58,061 smart.common - DEBUG - snes residual assemble (iter 1) finished in 0.002453 s (common.py:189)
#  2023-05-15 14:27:58,064 smart.model - DEBUG -   0 SNES Function norm 1.153983e+01 (model.py:1067)
# 2023-05-15 14:27:58,068 smart.common - DEBUG - snes jacobian assemble (iter 1) finished in 0.001278 s (common.py:189)
# 2023-05-15 14:27:58,093 smart.common - DEBUG - snes residual assemble (iter 2) finished in 0.002195 s (common.py:189)
# ╒════╤═════════════╤══════╤══════════════════╤═════════════╤══════════════╤════════════════╕
# │    │ name        │   id │   dimensionality │   num_cells │   num_facets │   num_vertices │
# ╞════╪═════════════╪══════╪══════════════════╪═════════════╪══════════════╪════════════════╡
# │  0 │ parent_mesh │    7 │                2 │        1000 │         1560 │            561 │
# ├────┼─────────────┼──────┼──────────────────┼─────────────┼──────────────┼────────────────┤
# │  1 │ junction    │   21 │                1 │          10 │           11 │             11 │
# ├────┼─────────────┼──────┼──────────────────┼─────────────┼──────────────┼────────────────┤
# │  2 │ PM1         │   27 │                2 │         500 │          785 │            286 │
# ╘════╧═════════════╧══════╧══════════════════╧═════════════╧══════════════╧════════════════╛
# 2023-05-15 14:27:58,097 smart.common - DEBUG - snes residual assemble (iter 3) finished in 0.001348 s (common.py:189)
# 2023-05-15 14:27:58,103 smart.common - DEBUG - snes residual assemble (iter 4) finished in 0.001287 s (common.py:189)
#  2023-05-15 14:27:58,109 smart.model - DEBUG -   1 SNES Function norm 1.022832e-14 (model.py:1067)
#
#
# ...........................................................................................................................
# ..... 2023-05-15 14:27:58,113 smart.model - INFO - Completed time-step 1 [time=0.010000, dt=0.010000] (model.py:1537) .....
# ...........................................................................................................................
#
#
# 2023-05-15 14:27:58,116 smart.common - DEBUG - snes initialize zero matrices finished in 0 s (common.py:205)
# 2023-05-15 14:27:58,119 smart.common - DEBUG - snes jacobian assemble        finished in 0.001278 s (common.py:205)
# 2023-05-15 14:27:58,121 smart.common - DEBUG - snes residual assemble        finished in 0.007284 s (common.py:205)
# 2023-05-15 14:27:58,125 smart.common - DEBUG - snes total assemble           finished in 0.008563 s (common.py:216)
# 2023-05-15 14:27:58,128 smart.common - DEBUG - snes total solve              finished in 0.063542 s (common.py:216)
# 2023-05-15 14:27:58,130 smart.common - DEBUG - snes all                      finished in 0.072105 s (common.py:222)
# 2023-05-15 14:27:58,133 smart.model - INFO - Non-linear solver iterations: 1 (model.py:1568)
# 2023-05-15 14:27
smart.common - DEBUG - snes initialize zero matrices finished in 0 s (common.py:205)
# 2023-05-15 14:27:59,210 smart.common - DEBUG - snes jacobian assemble        finished in 0.001482 s (common.py:205)
# 2023-05-15 14:27:59,211 smart.common - DEBUG - snes residual assemble        finished in 0.003905 s (common.py:205)
# 2023-05-15 14:27:59,213 smart.common - DEBUG - snes total assemble           finished in 0.005388 s (common.py:216)
# 2023-05-15 14:27:59,214 smart.common - DEBUG - snes total solve              finished in 0.026074 s (common.py:216)
# 2023-05-15 14:27:59,216 smart.common - DEBUG - snes all                      finished in 0.031462 s (common.py:222)
# 2023-05-15 14:27:59,218 smart.model - INFO - Non-linear solver iterations: 1 (model.py:1568)
# 2023-05-15 14:27:59,219 smart.model - INFO - Linear solver iterations: 1 (model.py:1572)
# 2023-05-15 14:27:59,228 smart.model - INFO - SNES converged reason: 3 (model.py:1576)
# 2023-05-15 14:27:59,230 smart.model - INFO - KSP converged reason: 2 (model.py:1580)
# 2023-05-15 14:27:59,231 smart.model - INFO - KSP residual norm: 1.76157905241259e-31 (model.py:1584)
# 2023-05-15 14:27:59,233 smart.common - DEBUG - Total time step               finished in 0.055315 s (common.py:205)
#
#
# ...........................................................................................................................
# ...........................................................................................................................
# ..... 2023-05-15 14:27:59,266 smart.model - INFO - Beginning time-step 9 [time=0.090000, dt=0.010000] (model.py:1521) .....
# ...........................................................................................................................
# ...........................................................................................................................
#
#
#  2023-05-15 14:27:59,268 smart.model - INFO - Solving using PETSc.SNES Solver (model.py:1530)
# 2023-05-15 14:27:59,271 smart.common - DEBUG - snes residual assemble (iter 1) finished in 0.000986 s (common.py:189)
#  2023-05-15 14:27:59,273 smart.model - DEBUG -   0 SNES Function norm 1.173945e+00 (model.py:1067)
# 2023-05-15 14:27:59,276 smart.common - DEBUG - snes jacobian assemble (iter 1) finished in 0.001491 s (common.py:189)
# 2023-05-15 14:27:59,279 smart.common - DEBUG - snes residual assemble (iter 2) finished in 0.001051 s (common.py:189)
# 2023-05-15 14:27:59,282 smart.common - DEBUG - snes residual assemble (iter 3) finished in 0.000827 s (common.py:189)
# 2023-05-15 14:27:59,285 smart.common - DEBUG - snes residual assemble (iter 4) finished in 0.000880 s (common.py:189)
#  2023-05-15 14:27:59,287 smart.model - DEBUG -   1 SNES Function norm 5.898717e-15 (model.py:1067)
#
#
# ...........................................................................................................................
# ..... 2023-05-15 14:27:59,289 smart.model - INFO - Completed time-step 9 [time=0.090000, dt=0.010000] (model.py:1537) .....
# ...........................................................................................................................
#
#
# 2023-05-15 14:27:59,291 smart.common - DEBUG - snes initialize zero matrices finished in 0 s (common.py:205)
# 2023-05-15 14:27:59,293 smart.common - DEBUG - snes jacobian assemble        finished in 0.001491 s (common.py:205)
# 2023-05-15 14:27:59,294 smart.common - DEBUG - snes residual assemble        finished in 0.003744 s (common.py:205)
# 2023-05-15 14:27:59,296 smart.common - DEBUG - snes total assemble           finished in 0.005235 s (common.py:216)
# 2023-05-15 14:27:59,304 smart.common - DEBUG - snes total solve              finished in 0.021222 s (common.py:216)
# 2023-05-15 14:27:59,306 smart.common - DEBUG - snes all                      finished in 0.026458 s (common.py:222)
# 2023-05-15 14:27:59,309 smart.model - INFO - Non-linear solver iterations: 1 (model.py:1568)
# 2023-05-15 14:27:59,311 smart.model - INFO - Linear solver iterations: 1 (model.py:1572)
# 2023-05-15 14:27:59,313 smart.model - INFO - SNES converged reason: 3 (model.py:1576)
# 2023-05-15 14:27:59,315 smart.model - INFO - KSP converged reason: 2 (model.py:1580)
# 2023-05-15 14:27:59,316 smart.model - INFO - KSP residual norm: 2.329414349147997e-31 (model.py:1584)
# 2023-05-15 14:27:59,318 smart.common - DEBUG - Total time step               finished in 0.052175 s (common.py:205)
#
#
# ............................................................................................................................
# ............................................................................................................................
# ..... 2023-05-15 14:27:59,353 smart.model - INFO - Beginning time-step 10 [time=0.100000, dt=0.010000] (model.py:1521) .....
# ............................................................................................................................
# ............................................................................................................................
#
#
#  2023-05-15 14:27:59,356 smart.model - INFO - Solving using PETSc.SNES Solver (model.py:1530)
# 2023-05-15 14:27:59,361 smart.common - DEBUG - snes residual assemble (iter 1) finished in 0.002156 s (common.py:189)
#  2023-05-15 14:27:59,364 smart.model - DEBUG -   0 SNES Function norm 1.021011e+00 (model.py:1067)
# 2023-05-15 14:27:59,367 smart.common - DEBUG - snes jacobian assemble (iter 1) finished in 0.001714 s (common.py:189)
# 2023-05-15 14:27:59,370 smart.common - DEBUG - snes residual assemble (iter 2) finished in 0.000766 s (common.py:189)
# 2023-05-15 14:27:59,373 smart.common - DEBUG - snes residual assemble (iter 3) finished in 0.001144 s (common.py:189)
# 2023-05-15 14:27:59,377 smart.common - DEBUG - snes residual assemble (iter 4) finished in 0.000811 s (common.py:189)
#  2023-05-15 14:27:59,379 smart.model - DEBUG -   1 SNES Function norm 4.882099e-15 (model.py:1067)
#
#
# ............................................................................................................................
# ..... 2023-05-15 14:27:59,381 smart.model - INFO - Completed time-step 10 [time=0.100000, dt=0.010000] (model.py:1537) .....
# ............................................................................................................................
#
#
# 2023-05-15 14:27:59,383 smart.common - DEBUG - snes initialize zero matrices finished in 0 s (common.py:205)
# 2023-05-15 14:27
smart.common - DEBUG - snes jacobian assemble (iter 1) finished in 0.001998 s (common.py:189)
# 2023-05-15 14:28:10,956 smart.common - DEBUG - snes residual assemble (iter 2) finished in 0.002103 s (common.py:189)
# 2023-05-15 14:28:10,963 smart.common - DEBUG - snes residual assemble (iter 3) finished in 0.002045 s (common.py:189)
# 2023-05-15 14:28:10,977 smart.common - DEBUG - snes residual assemble (iter 4) finished in 0.001607 s (common.py:189)
#  2023-05-15 14:28:10,980 smart.model - DEBUG -   1 SNES Function norm 5.147587e-15 (model.py:1067)
#
#
# ............................................................................................................................
# ..... 2023-05-15 14:28:10,984 smart.model - INFO - Completed time-step 98 [time=0.980000, dt=0.010000] (model.py:1537) .....
# ............................................................................................................................
#
#
# 2023-05-15 14:28:10,988 smart.common - DEBUG - snes initialize zero matrices finished in 0 s (common.py:205)
# 2023-05-15 14:28:10,993 smart.common - DEBUG - snes jacobian assemble        finished in 0.001998 s (common.py:205)
# 2023-05-15 14:28:10,996 smart.common - DEBUG - snes residual assemble        finished in 0.006747 s (common.py:205)
# 2023-05-15 14:28:10,999 smart.common - DEBUG - snes total assemble           finished in 0.008746 s (common.py:216)
# 2023-05-15 14:28:11,001 smart.common - DEBUG - snes total solve              finished in 0.049074 s (common.py:216)
# 2023-05-15 14:28:11,004 smart.common - DEBUG - snes all                      finished in 0.057821 s (common.py:222)
# 2023-05-15 14:28:11,007 smart.model - INFO - Non-linear solver iterations: 1 (model.py:1568)
# 2023-05-15 14:28:11,009 smart.model - INFO - Linear solver iterations: 1 (model.py:1572)
# 2023-05-15 14:28:11,011 smart.model - INFO - SNES converged reason: 3 (model.py:1576)
# 2023-05-15 14:28:11,013 smart.model - INFO - KSP converged reason: 2 (model.py:1580)
# 2023-05-15 14:28:11,015 smart.model - INFO - KSP residual norm: 3.532868887533938e-33 (model.py:1584)
# 2023-05-15 14:28:11,018 smart.common - DEBUG - Total time step               finished in 0.083691 s (common.py:205)
#
#
# ............................................................................................................................
# ............................................................................................................................
# ..... 2023-05-15 14:28:11,079 smart.model - INFO - Beginning time-step 99 [time=0.990000, dt=0.010000] (model.py:1521) .....
# ............................................................................................................................
# ............................................................................................................................
#
#
#  2023-05-15 14:28:11,081 smart.model - INFO - Solving using PETSc.SNES Solver (model.py:1530)
# 2023-05-15 14:28:11,084 smart.common - DEBUG - snes residual assemble (iter 1) finished in 0.001142 s (common.py:189)
#  2023-05-15 14:28:11,087 smart.model - DEBUG -   0 SNES Function norm 1.899063e-02 (model.py:1067)
# 2023-05-15 14:28:11,099 smart.common - DEBUG - snes jacobian assemble (iter 1) finished in 0.001562 s (common.py:189)
# 2023-05-15 14:28:11,105 smart.common - DEBUG - snes residual assemble (iter 2) finished in 0.002204 s (common.py:189)
# 2023-05-15 14:28:11,109 smart.common - DEBUG - snes residual assemble (iter 3) finished in 0.001453 s (common.py:189)
# 2023-05-15 14:28:11,113 smart.common - DEBUG - snes residual assemble (iter 4) finished in 0.001477 s (common.py:189)
#  2023-05-15 14:28:11,116 smart.model - DEBUG -   1 SNES Function norm 5.031779e-15 (model.py:1067)
#
#
# ............................................................................................................................
# ..... 2023-05-15 14:28:11,119 smart.model - INFO - Completed time-step 99 [time=0.990000, dt=0.010000] (model.py:1537) .....
# ............................................................................................................................
#
#
# 2023-05-15 14:28:11,122 smart.common - DEBUG - snes initialize zero matrices finished in 0 s (common.py:205)
# 2023-05-15 14:28:11,125 smart.common - DEBUG - snes jacobian assemble        finished in 0.001562 s (common.py:205)
# 2023-05-15 14:28:11,128 smart.common - DEBUG - snes residual assemble        finished in 0.006277 s (common.py:205)
# 2023-05-15 14:28:11,131 smart.common - DEBUG - snes total assemble           finished in 0.007840 s (common.py:216)
# 2023-05-15 14:28:11,134 smart.common - DEBUG - snes total solve              finished in 0.040214 s (common.py:216)
# 2023-05-15 14:28:11,137 smart.common - DEBUG - snes all                      finished in 0.048054 s (common.py:222)
# 2023-05-15 14:28:11,140 smart.model - INFO - Non-linear solver iterations: 1 (model.py:1568)
# 2023-05-15 14:28:11,143 smart.model - INFO - Linear solver iterations: 1 (model.py:1572)
# 2023-05-15 14:28:11,146 smart.model - INFO - SNES converged reason: 3 (model.py:1576)
# 2023-05-15 14:28:11,149 smart.model - INFO - KSP converged reason: 2 (model.py:1580)
# 2023-05-15 14:28:11,152 smart.model - INFO - KSP residual norm: 4.962051281635905e-33 (model.py:1584)
# 2023-05-15 14:28:11,156 smart.common - DEBUG - Total time step               finished in 0.077079 s (common.py:205)
#
#
# .............................................................................................................................
# .............................................................................................................................
# ..... 2023-05-15 14:28:11,223 smart.model - INFO - Beginning time-step 100 [time=1.000000, dt=0.010000] (model.py:1521) .....
# .............................................................................................................................
# .............................................................................................................................
#
#
#  2023-05-15 14:28:11,226 smart.model - INFO - Solving using PETSc.SNES Solver (model.py:1530)
# 2023-05-15 14:28:11,231 smart.common - DEBUG - snes residual assemble (iter 1) finished in 0.001700 s (common.py:189)
#  2023-05-15 14:28:11,234 smart.model - DEBUG -   0 SNES Function norm 1.860252e-02 (model.py:1067)
# 2023-05-15 14:28:11,240 smart.common - DEBUG - snes jacobian assemble (iter 1) finished in 0.002372 s (common.py:189)
# 2023-05-15 14:28:11,251 smart.common - DEBUG - snes residual assemble (iter 2) finished in 0.001817 s (common.py:189)
# 2023-05-15 14:28:11,257 smart.common - DEBUG - snes residual assemble (iter 3) finished in 0.001795 s (common.py:189)
# 2023-05-15 14:28:11,264 smart.common - DEBUG - snes residual assemble (iter 4) finished in 0.002692 s (common.py:189)
#  2023-05-15 14:28:11,268 smart.model - DEBUG -   1 SNES Function norm 4.752138e-15 (model.py:1067)
#
#
# .............................................................................................................................
# ..... 2023-05-15 14:28:11,272 smart.model - INFO - Completed time-step 100 [time=1.000000, dt=0.010000] (model.py:1537) .....
# .............................................................................................................................
#
#
# 2023-05-15 14:28:11,275 smart.common - DEBUG - snes initialize zero matrices finished in 0 s (common.py:205)
# 2023-05-15 14:28:11,277 smart.common - DEBUG - snes jacobian assemble        finished in 0.002372 s (common.py:205)
# 2023-05-15 14:28:11,280 smart.common - DEBUG - snes residual assemble        finished in 0.008005 s (common.py:205)
# 2023-05-15 14:28:11,282 smart.common - DEBUG - snes total assemble           finished in 0.010378 s (common.py:216)
# 2023-05-15 14:28:11,284 smart.common - DEBUG - snes total solve              finished in 0.043179 s (common.py:216)
# 2023-05-15 14:28:11,287 smart.common - DEBUG - snes all                      finished in 0.053557 s (common.py:222)
# 2023-05-15 14:28:11,290 smart.model - INFO - Non-linear solver iterations: 1 (model.py:1568)
# 2023-05-15 14:28:11,293 smart.model - INFO - Linear solver iterations: 1 (model.py:1572)
# 2023-05-15 14:28:11,295 smart.model - INFO - SNES converged reason: 3 (model.py:1576)
# 2023-05-15 14:28:11,297 smart.model - INFO - KSP converged reason: 2 (model.py:1580)
# 2023-05-15 14:28:11,299 smart.model - INFO - KSP residual norm: 3.406459707761966e-33 (model.py:1584)
# 2023-05-15 14:28:11,302 smart.common - DEBUG - Total time step               finished in 0.079210 s (common.py:205)

# %%
# %matplotlib inline
# plt.plot(radiusVec, ss_vec, 'ro')
# radiusTest = np.logspace(0,1,100)
# thieleMod = radiusTest / 1.0
# k_kin = 50
# k_p = 10
# cT = 1
# D = 10
# C1 = k_kin*cT*radiusTest**2/((3*D*(np.sqrt(k_p/D)-(1/radiusTest)) + k_kin*radiusTest)*np.exp(thieleMod) +
#         (3*D*(np.sqrt(k_p/D)+(1/radiusTest))-k_kin*radiusTest)*np.exp(-thieleMod))
# cA = (6*C1/radiusTest)*(np.cosh(thieleMod)/thieleMod - np.sinh(thieleMod)/thieleMod**2)
# plt.plot(radiusTest, cA)
# plt.xlabel("Cell radius (μm)")
# plt.ylabel("Steady state concentration (μM)")
# plt.legend(("SMART simulation", "Analytical solution"))
